# %%
#you need the image 2008_000237.jpg from Pascal1K, or change it! ;-)

# !mkdir -p _temp
# !echo `pwd`/images/2008_000237.jpg > _temp/det_input.txt

#equivalent to:
#!./python/detect.py --crop_mode=selective_search --pretrained_model=models/bvlc_reference_rcnn_ilsvrc13/bvlc_reference_rcnn_ilsvrc13.caffemodel --model_def=models/bvlc_reference_rcnn_ilsvrc13/deploy.prototxt --raw_scale=255 _temp/det_input.txt _temp/det_output.h5
# !./python/my_detect.py --crop_mode=selective_search --pretrained_model=models/bvlc_reference_rcnn_ilsvrc13/bvlc_reference_rcnn_ilsvrc13.caffemodel --model_def=models/bvlc_reference_rcnn_ilsvrc13/deploy.prototxt --raw_scale=255 _temp/det_input.txt _temp/det_output.h5
#one can add: --mean_file=python/caffe/imagenet/ilsvrc_2012_mean.npy 
#or: --gpu
# Out:
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I1007 17:13:16.200726 2038571792 net.cpp:39] Initializing net from parameters:
# name: "R-CNN-ilsvrc13"
# layers {
#   bottom: "data"
#   top: "conv1"
#   name: "conv1"
#   type: CONVOLUTION
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#   }
# }
# layers {
#   bottom: "conv1"
#   top: "conv1"
#   name: "relu1"
#   type: RELU
# }
# layers {
#   bottom: "conv1"
#   top: "pool1"
#   name: "pool1"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool1"
#   top: "norm1"
#   name: "norm1"
#   type: LRN
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layers {
#   bottom: "norm1"
#   top: "conv2"
#   name: "conv2"
#   type: CONVOLUTION
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#   }
# }
# layers {
#   bottom: "conv2"
#   top: "conv2"
#   name: "relu2"
#   type: RELU
# }
# layers {
#   bottom: "conv2"
#   top: "pool2"
#   name: "pool2"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool2"
#   top: "norm2"
#   name: "norm2"
#   type: LRN
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layers {
#   bottom: "norm2"
#   top: "conv3"
#   name: "conv3"
#   type: CONVOLUTION
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#   }
# }
# layers {
#   bottom: "conv3"
#   top: "conv3"
#   name: "relu3"
#   type: RELU
# }
# layers {
#   bottom: "conv3"
#   top: "conv4"
#   name: "conv4"
#   type: CONVOLUTION
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#   }
# }
# layers {
#   bottom: "conv4"
#   top: "conv4"
#   name: "relu4"
#   type: RELU
# }
# layers {
#   bottom: "conv4"
#   top: "conv5"
#   name: "conv5"
#   type: CONVOLUTION
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#   }
# }
# layers {
#   bottom: "conv5"
#   top: "conv5"
#   name: "relu5"
#   type: RELU
# }
# layers {
#   bottom: "conv5"
#   top: "pool5"
#   name: "pool5"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool5"
#   top: "fc6"
#   name: "fc6"
#   type: INNER_PRODUCT
#   inner_product_param {
#     num_output: 4096
#   }
# }
# layers {
#   bottom: "fc6"
#   top: "fc6"
#   name: "relu6"
#   type: RELU
# }
# layers {
#   bottom: "fc6"
#   top: "fc6"
#   name: "drop6"
#   type: DROPOUT
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layers {
#   bottom: "fc6"
#   top: "fc7"
#   name: "fc7"
#   type: INNER_PRODUCT
#   inner_product_param {
#     num_output: 4096
#   }
# }
# layers {
#   bottom: "fc7"
#   top: "fc7"
#   name: "relu7"
#   type: RELU
# }
# layers {
#   bottom: "fc7"
#   top: "fc7"
#   name: "drop7"
#   type: DROPOUT
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layers {
#   bottom: "fc7"
#   top: "fc-rcnn"
#   name: "fc-rcnn"
#   type: INNER_PRODUCT
#   inner_product_param {
#     num_output: 200
#   }
# }
# input: "data"
# input_dim: 10
# input_dim: 3
# input_dim: 227
# input_dim: 227
# I1007 17:13:16.201688 2038571792 net.cpp:358] Input 0 -> data
# I1007 17:13:16.201726 2038571792 net.cpp:67] Creating Layer conv1
# I1007 17:13:16.201733 2038571792 net.cpp:394] conv1 <- data
# I1007 17:13:16.201740 2038571792 net.cpp:356] conv1 -> conv1
# I1007 17:13:16.201751 2038571792 net.cpp:96] Setting up conv1
# I1007 17:13:16.201791 2038571792 net.cpp:103] Top shape: 10 96 55 55 (2904000)
# I
# I1007 17:13:16.341315 2038571792 net.cpp:172] pool2 does not need backward computation.
# I1007 17:13:16.341320 2038571792 net.cpp:172] relu2 does not need backward computation.
# I1007 17:13:16.341325 2038571792 net.cpp:172] conv2 does not need backward computation.
# I1007 17:13:16.341330 2038571792 net.cpp:172] norm1 does not need backward computation.
# I1007 17:13:16.341333 2038571792 net.cpp:172] pool1 does not need backward computation.
# I1007 17:13:16.341338 2038571792 net.cpp:172] relu1 does not need backward computation.
# I1007 17:13:16.341342 2038571792 net.cpp:172] conv1 does not need backward computation.
# I1007 17:13:16.341347 2038571792 net.cpp:208] This network produces output fc-rcnn
# I1007 17:13:16.341481 2038571792 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I1007 17:13:16.341500 2038571792 net.cpp:219] Network initialization done.
# I1007 17:13:16.341506 2038571792 net.cpp:220] Memory required for data: 62425920
# Loading input...
# script dirname:
# /Users/gabrielsynnaeve/labs/selective_search_ijcv_with_python
# matlab command:
# selective_search_rcnn({'/Users/gabrielsynnaeve/labs/caffe/images/2008_000237.jpg'}, '/var/folders/04/dhdz5lq9313_n_wy8yz1gpmm0000gq/T/tmpdjuVLE.mat')
#
# matlab command full:
# matlab -nojvm -r "try; selective_search_rcnn({'/Users/gabrielsynnaeve/labs/caffe/images/2008_000237.jpg'}, '/var/folders/04/dhdz5lq9313_n_wy8yz1gpmm0000gq/T/tmpdjuVLE.mat'); catch; exit; end; exit"
# blobs: ['data', 'conv1', 'pool1', 'norm1', 'conv2', 'pool2', 'norm2', 'conv3', 'conv4', 'conv5', 'pool5', 'fc6', 'fc7', 'fc-rcnn']
# out keys: ['fc-rcnn', 'fc7']
# [('data', (10, 3, 227, 227)), ('conv1', (10, 96, 55, 55)), ('pool1', (10, 96, 27, 27)), ('norm1', (10, 96, 27, 27)), ('conv2', (10, 256, 27, 27)), ('pool2', (10, 256, 13, 13)), ('norm2', (10, 256, 13, 13)), ('conv3', (10, 384, 13, 13)), ('conv4', (10, 384, 13, 13)), ('conv5', (10, 256, 13, 13)), ('pool5', (10, 256, 6, 6)), ('fc6', (10, 4096, 1, 1)), ('fc7', (10, 4096, 1, 1)), ('fc-rcnn', (10, 200, 1, 1))]
# Processed 2542 windows in 108.937 s.
# /Users/gabrielsynnaeve/anaconda/lib/python2.7/site-packages/pandas/io/pytables.py:2453: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->['fc7', 'prediction']]
#
#   warnings.warn(ws, PerformanceWarning)
# Saved to _temp/det_output.h5 in 0.297 s.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_hdf('_temp/det_output.h5', 'df')
print(df.shape)
print(df.iloc[0])
# Out:
# (2542, 6)
# fc7           [1.62737, 0.298038, 0.264018, 1.06826, 0.0, 0....
# prediction    [-2.46781, -2.63598, -2.60766, -2.67273, -2.29...
# ymin                                                        280
# xmin                                                        204
# ymax                                                        375
# xmax                                                        500
# Name: /Users/gabrielsynnaeve/labs/caffe/images/2008_000237.jpg, dtype: object

# %%
fc7 = df.iloc[0]['fc7']
print fc7.shape
plt.subplot(2, 1, 1)
plt.plot(fc7)
plt.subplot(2, 1, 2)
_ = plt.hist(fc7[fc7 > 0], bins=100)
# Out:
# (4096,)

# %%
with open('./data/ilsvrc12/det_synset_words.txt') as f:
    labels_df = pd.DataFrame([
        {
            'synset_id': l.strip().split(' ')[0],
            'name': ' '.join(l.strip().split(' ')[1:]).split(',')[0]
        }
        for l in f.readlines()
    ])
labels_df.sort('synset_id')
predictions_df = pd.DataFrame(np.vstack(df.prediction.values), columns=labels_df['name'])
print(predictions_df.iloc[0])
# Out:
# name
# accordion      -2.467812
# airplane       -2.635976
# ant            -2.607662
# antelope       -2.672733
# apple          -2.292799
# armadillo      -2.624982
# artichoke      -1.965171
# axe            -2.943621
# baby bed       -3.507530
# backpack       -2.668072
# bagel          -2.062805
# balance beam   -2.270076
# banana         -3.033584
# band aid       -1.957657
# banjo          -2.715515
# ...
# trombone        -2.410629
# trumpet         -2.952126
# turtle          -2.714993
# tv or monitor   -2.621704
# unicycle        -2.046555
# vacuum          -2.101053
# violin          -2.394591
# volleyball      -2.413300
# waffle iron     -2.034665
# washer          -2.410691
# water bottle    -2.064602
# watercraft      -2.452874
# whale           -2.786521
# wine bottle     -2.317564
# zebra           -2.266912
# Name: 0, Length: 200, dtype: float32

# %%
plt.gray()
plt.matshow(predictions_df.values)
plt.xlabel('Classes')
plt.ylabel('Windows')

# %%
max_s = predictions_df.max(0)
max_s.sort(ascending=False)
print(max_s[:10])
# Out:
# name
# car                     0.624620
# person                  0.610866
# snowplow               -0.195289
# plate rack             -0.576437
# crutch                 -0.600598
# tv or monitor          -0.681185
# bus                    -0.697354
# puck                   -0.766750
# hat with a wide brim   -0.832071
# bench                  -0.849278
# dtype: float32

# %%
# Find, print, and display the top detections: car, person, snowplow.
i = predictions_df['car'].argmax()
j = predictions_df['person'].argmax()
k = predictions_df['snowplow'].argmax()

# Show top predictions for top detection.
f = pd.Series(df['prediction'].iloc[i], index=labels_df['name'])
print('Top detection:')
print(f.order(ascending=False)[:5])
print('')

# Show top predictions for second-best detection.
f = pd.Series(df['prediction'].iloc[j], index=labels_df['name'])
print('Second-best detection:')
print(f.order(ascending=False)[:5])
print('')

# Show top predictions for third-best detection.
f = pd.Series(df['prediction'].iloc[k], index=labels_df['name'])
print('Third-best detection:')
print(f.order(ascending=False)[:5])

# Show top detection in red, second-best top detection in blue.
im = plt.imread('images/2008_000237.jpg')
plt.imshow(im)
currentAxis = plt.gca()

det = df.iloc[i]
coords = (det['xmin'], det['ymin']), det['xmax'] - det['xmin'], det['ymax'] - det['ymin']
currentAxis.add_patch(plt.Rectangle(*coords, fill=False, edgecolor='r', linewidth=5))

det = df.iloc[j]
coords = (det['xmin'], det['ymin']), det['xmax'] - det['xmin'], det['ymax'] - det['ymin']
currentAxis.add_patch(plt.Rectangle(*coords, fill=False, edgecolor='b', linewidth=5))

det = df.iloc[k]
coords = (det['xmin'], det['ymin']), det['xmax'] - det['xmin'], det['ymax'] - det['ymin']
currentAxis.add_patch(plt.Rectangle(*coords, fill=False, edgecolor='g', linewidth=5))
# Out:
# Top detection:
# name
# car                0.624620
# flower pot        -1.184519
# bowl              -1.305960
# swimming trunks   -1.379616
# starfish          -1.391312
# dtype: float32
#
# Second-best detection:
# name
# person            0.610866
# backpack         -1.308766
# purse            -1.328411
# computer mouse   -1.396016
# table            -1.438188
# dtype: float32
#
# Third-best detection:
# name
# snowplow    -0.195289
# car         -1.225220
# pizza       -1.348878
# red panda   -1.383343
# pretzel     -1.479257
# dtype: float32

# %%
predictions_df['person'][predictions_df['person'].argsort()][-5:]
# Out:
# person
# 1442     -1.094553
# 376      -0.968008
# 413      -0.900976
# 87       -0.823153
# 252       0.610866
# Name: person, dtype: float32

# %%
import heapq
import numpy as np

n_ilocs, n_args = df.shape

# TODO SHOULD NORMALIZE THE PROBS !

#top_20 = []
all_values = np.sort(predictions_df.values.flatten())
lower_top19 = all_values[-20]
lower_top20 = all_values[-21]
print all_values

im = plt.imread('images/2008_000237.jpg')
plt.imshow(im)
currentAxis = plt.gca()
colors = ['r', 'g', 'b', 'y', 'c', 'm', 'purple', 'k', 'w']
used_colors = {}

predictions_df = pd.DataFrame(np.vstack(df.prediction.values), columns=labels_df['name'])
print type(predictions_df)

def draw_box(tag, i):
    print tag, i,
    color = colors[len(used_colors) % len(colors)]
    if tag in used_colors:
        color = used_colors[tag]
    else:
        used_colors[tag] = color
    det = df.iloc[i]
    xmin = det['xmin']
    ymin = det['ymin']
    xmax = det['xmax']
    ymax = det['ymax']
    print "(", xmin, ymin, xmax, ymax, ")"
    coords = (xmin, ymin), xmax - xmin, ymax - ymin
    currentAxis.add_patch(plt.Rectangle(*coords, fill=False, edgecolor=color, linewidth=5))
    
i_set = set()
fc7s = []

n_boxes = 0
for i in xrange(n_ilocs):
    for tag in predictions_df.iloc[i].keys():
        prob = predictions_df.iloc[i][tag]
        if prob < lower_top20 or n_boxes >= 20:
            continue
        else:
            n_boxes += 1
            draw_box(tag, i)
            if i not in i_set:
                fc7s.append(df.iloc[i]['fc7'])
                i_set.add(i)

           
print used_colors
print len(fc7s)
print fc7s[0]
# Out:
# [-5.74325323 -5.41117239 -5.33600473 ...,  0.59749675  0.61086631
#   0.62461972]
# <class 'pandas.core.frame.DataFrame'>
# car
#  170 ( 173 100 321 152 )
# bus
#  206 ( 297 103 468 268 )
# car
#  237 ( 374 168 468 249 )
# tv or monitor 237 ( 374 168 468 249 )
# person
#  252 ( 215 338 242 375 )
# car
#  305 ( 128 107 315 160 )
# car
#  327 ( 111 93 500 279 )
# plate rack
#  415 ( 214 171 272 234 )
# car
#  449 ( 151 107 316 154 )
# car
#  487 ( 161 107 316 152 )
# car
#  522 ( 183 111 316 154 )
# snowplow
#  536 ( 354 167 500 279 )
# car
#  553 ( 374 168 468 268 )
# car
#  592 ( 173 100 320 152 )
# crutch 594 ( 89 44 151 270 )
# car
#  812 ( 185 111 316 152 )
# car
#  1017 ( 128 107 315 152 )
# snowplow
#  1161 ( 356 167 500 281 )
# car
#  1245 ( 374 173 468 249 )
# car
#  1815 ( 185 111 315 152 )
# {'snowplow': 'm', 'car': 'r', 'tv or monitor': 'b', 'crutch': 'purple', 'person': 'y', 'bus': 'g', 'plate rack': 'c'}
# 19
# [ 0.  0.  0. ...,  0.  0.  0.]
